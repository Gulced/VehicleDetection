# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.7/898.7 kB 53.3 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.6/112.6 GB disk)

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/ObjectDetection/VehiclesDetection/dataset.yaml epochs=30 imgsz=416 batch=5 project=/content/drive/MyDrive/ObjectDetection/VehiclesDetection/TrainingResults name=vehiclesDetection
# Out:
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls /content/drive/MyDrive/ObjectDetection/VehiclesDetection/
# Out:
# TrainingResults

# %%
dataset_yaml_content = """
train: /content/drive/MyDrive/ObjectDetection/VehiclesDetection/train
val: /content/drive/MyDrive/ObjectDetection/VehiclesDetection/val

nc: 5  # Sınıf sayısı
names: ['car', 'bus', 'truck', 'motorcycle', 'bicycle']  # Sınıf isimleri
"""
with open('/content/drive/MyDrive/ObjectDetection/VehiclesDetection/dataset.yaml', 'w') as f:
    f.write(dataset_yaml_content)
print("dataset.yaml dosyası oluşturuldu!")
# Out:
# dataset.yaml dosyası oluşturuldu!

# %%
# !ls /content/drive/MyDrive/ObjectDetection/VehiclesDetection/
# Out:
# dataset.yaml  TrainingResults

# %%
# !ls /content/drive/MyDrive/ObjectDetection/VehiclesDetection/val
# Out:
# images	labels

# %%
# !yolo train task=detect model=yolov8s.pt data=/content/drive/MyDrive/ObjectDetection/VehiclesDetection/dataset.yaml epochs=10 imgsz=416 batch=5
# Out:
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/ObjectDetection/VehiclesDetection/dataset.yaml epochs=30 imgsz=416 batch=5 project=/content/drive/MyDrive/ObjectDetection/VehiclesDetection/TrainingResults name=vehiclesDetection
# Out:
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect \
      mode=predict \
      model=/content/drive/MyDrive/ObjectDetection/VehiclesDetection/TrainingResults/vehiclesDetection8/weights/best.pt \
      conf=0.50 \
      source=/content/drive/MyDrive/ObjectDetection/VehiclesDetection/test/images
# Out:
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,127,519 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/126 /content/drive/MyDrive/ObjectDetection/VehiclesDetection/test/images/00dea1edf14f09ab_jpg.rf.3f17c8790a68659d03b1939a59ccda80.jpg: 416x416 1 car, 10.2ms
# image 2/126 /content/drive/MyDrive/ObjectDetection/VehiclesDetection/test/images/00dea1edf14f09ab_jpg.rf.KJ730oDTFPdXdJxvSLnX.jpg: 416x416 1 car, 25.6ms
# image 3/126 /content/drive/MyDrive/ObjectDetection/VehiclesDetection/test/images/00e481ea1a520175_jpg.rf.6e6a8b3b45c9a11d106958f88ff714ea.jpg: 416x416 3 buss, 13.8ms
# image 4/126 /content/drive/MyDrive/ObjectDetection/VehiclesDetection/test/images/00e481ea1a520175_jpg.rf.MV6sZ8QCFwFeMYaI2tHm.jpg: 416x416 3 buss, 12.1ms
# image 5/126 /content/drive/MyDrive/ObjectDetection/VehiclesDetection/test/images/08c8b73e0c2e296e_jpg.rf.7IkYAamjZhnwsoXSrwKt.jpg: 416x416 2 buss, 10.5ms
# ...

# %%
# !cp -r /content/runs/detect/predict /content/drive/MyDrive/ObjectDetection/VehiclesDetection/DetectionResults/

# %%
# !yolo task=detect \
      mode=predict \
      model=/content/drive/MyDrive/ObjectDetection/VehiclesDetection/TrainingResults/vehiclesDetection8/weights/best.pt \
      conf=0.75 \
      source=/content/drive/MyDrive/ObjectDetection/VehiclesDetection/TestVideos
# Out:
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,127,519 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/1 (frame 1/2362) /content/drive/MyDrive/ObjectDetection/VehiclesDetection/TestVideos/TrafficPolice.mp4: 256x416 2 trucks, 39.0ms
# video 1/1 (frame 2/2362) /content/drive/MyDrive/ObjectDetection/VehiclesDetection/TestVideos/TrafficPolice.mp4: 256x416 3 trucks, 8.8ms
# video 1/1 (frame 3/2362) /content/drive/MyDrive/ObjectDetection/VehiclesDetection/TestVideos/TrafficPolice.mp4: 256x416 2 trucks, 9.3ms
# video 1/1 (frame 4/2362) /content/drive/MyDrive/ObjectDetection/VehiclesDetection/TestVideos/TrafficPolice.mp4: 256x416 3 trucks, 9.1ms
# video 1/1 (frame 5/2362) /content/drive/MyDrive/ObjectDetection/VehiclesDetection/TestVideos/TrafficPolice.mp4: 256x416 3 trucks, 9.0ms
# video 1/1 (frame 6/2362) /content/drive/MyDrive/ObjectDetection/VehiclesDetection/TestVideos/TrafficPolice.mp4: 256x416 4 trucks, 9.2ms
# ...

# %%
# !cp -r /content/runs/detect/predict /content/drive/MyDrive/ObjectDetection/VehiclesDetection/DetectionResults/

# %%
# !yolo mode=export \
      model=/content/drive/MyDrive/ObjectDetection/VehiclesDetection/TrainingResults/vehiclesDetection8/weights/best.pt \
      format=onnx
# Out:
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.00GHz)
# Model summary (fused): 168 layers, 11,127,519 parameters, 0 gradients, 28.4 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/ObjectDetection/VehiclesDetection/TrainingResults/vehiclesDetection8/weights/best.pt' with input shape (1, 3, 416, 416) BCHW and output shape(s) (1, 9, 3549) (21.4 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0', 'onnxslim', 'onnxruntime'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 305.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.9/142.9 kB 351.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 206.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 157.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 174.7 MB/s eta 0:00:00
# ...
#
# ...

# %%
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/ObjectDetection/VehiclesDetection/TrainingResults/vehiclesDetection8/weights/best.pt')


metrics = model.val()
# Out:
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,127,519 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/drive/MyDrive/ObjectDetection/VehiclesDetection/val/labels.cache... 250 images, 0 backgrounds, 0 corrupt: 100%|██████████| 250/250 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 16/16 [00:04<00:00,  3.22it/s]
#                    all        250        454      0.699      0.541      0.624      0.487
#                    car         50         64      0.751       0.85      0.894      0.782
#                    bus         30         46      0.772      0.652      0.757      0.633
#                  truck         90        238      0.743      0.412      0.528      0.368
#             motorcycle         42         46      0.656      0.522      0.558      0.365
# ...

# %% [markdown]
# # Yeni Bölüm
